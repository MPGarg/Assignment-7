# %% [markdown]
# <a href="https://colab.research.google.com/github/MPGarg/Assignment-7/blob/main/EVA8_Assigment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
from __future__ import print_function
import torch.optim as optim
from torchvision import datasets, transforms
import torch
import torch.nn.functional as F
import torchvision
from torchsummary import summary
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
#!pip install -U albumentations
import albumentations as A
from albumentations.pytorch import ToTensorV2

# %% [markdown]
# # Import files from GIT Hub

# %%
# !git clone https://github.com/MPGarg/common_repo.git
# Out:
# Cloning into 'common_repo'...
# remote: Enumerating objects: 142, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 142 (delta 33), reused 50 (delta 23), pack-reused 61
# Receiving objects: 100% (142/142), 47.90 KiB | 2.39 MiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %% [markdown]
# # ResNet18 class is imported

# %%
from common_repo.models import resnet
from common_repo.models.resnet import ResNet18

# %% [markdown]
# # Import Other fuctions

# %%
from common_repo import main, utils
from common_repo.utils import *    
from common_repo.main import train, test, train_test_model

# %% [markdown]
# # Assign device

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
view_model = ResNet18().to(device)
summary(view_model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
# ...

# %% [markdown]
# # Show sample images and Load dataset

# %%
model = ResNet18().to(device)
trainset_mod, trainloader_mod, testset_mod, testloader_mod = process_dataset()
# Out:
# ...
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Train & Test Model

# %%
model_tr, wrong_prediction_list, train_losses, train_acc, test_losses, test_acc = train_test_model(model, trainloader_mod, testloader_mod, norm_type='BN', EPOCHS=20, lr=0.01, device=device,sched=' ')
# Out:
# EPOCH: 1
# 100%|██████████| 391/391 [00:43<00:00,  8.96it/s]
# Average Training Loss=0.011175650593042374, Accuracy=47.974
# Test set: Average loss: 0.0093, Accuracy: 5876/10000 (58.76%)
#
# EPOCH: 2
# 100%|██████████| 391/391 [00:44<00:00,  8.86it/s]
# Average Training Loss=0.007561429578065872, Accuracy=65.524
# Test set: Average loss: 0.0078, Accuracy: 6736/10000 (67.36%)
#
# EPOCH: 3
# 100%|██████████| 391/391 [00:45<00:00,  8.69it/s]
# Average Training Loss=0.006073884189128876, Accuracy=72.888
# Test set: Average loss: 0.0056, Accuracy: 7567/10000 (75.67%)
#
# EPOCH: 4
# 100%|██████████| 391/391 [00:45<00:00,  8.57it/s]
# Average Training Loss=0.005138185279965401, Accuracy=76.986
# Test set: Average loss: 0.0052, Accuracy: 7792/10000 (77.92%)
#
# EPOCH: 5
# 100%|██████████| 391/391 [00:45<00:00,  8.57it/s]
# Average Training Loss=0.004446439939141273, Accuracy=79.876
# Test set: Average loss: 0.0043, Accuracy: 8113/10000 (81.13%)
#
# EPOCH: 6
# ...

# %% [markdown]
# # Display Validation Accuracy & Loss

# %%
plot_acc_loss(train_acc,train_losses,test_acc,test_losses)

# %% [markdown]
# # Display wrong prediction

# %%
display_incorrect_pred(wrong_prediction_list)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# # GradCam

# %%
target_layers = ["layer1", "layer2","layer3", "layer4"]
torch.autograd.set_detect_anomaly(True)

# %%
from common_repo.utils import generate_gradcam, plot_gradcam
gradcam_output, probs, predicted_classes = generate_gradcam(wrong_prediction_list[:10], model_tr, target_layers, device)
# Out:
# torch.Size([10, 10])
# Generating Grad-CAM @layer1
# Generating Grad-CAM @layer2
# Generating Grad-CAM @layer3
# Generating Grad-CAM @layer4
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
plot_gradcam(gradcam_output, target_layers, classes, (3,32,32), predicted_classes, wrong_prediction_list[:10])
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
